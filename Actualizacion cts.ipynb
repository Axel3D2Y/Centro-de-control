# %%
import pandas as pd

# %%
cts = pd.read_excel(r"C:\Users\centro.control\Downloads\Tickets de Recursos Humanos (CTS) (respuestas) (16).xlsx")
# Out:
# c:\Users\centro.control\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Z349 is marked as a date but the serial value 6948701.0 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
cts
# Out:
#       Folio            Estatus Fecha compromiso de cobertura     Procede  \
# 0         1            Abierto                           NaN  No procede
# 1         2  Cerrado con éxito    2024-07-12 17:03:55.584000     Procede
# 2         3  Cerrado con éxito    2024-07-12 17:05:45.312000     Procede
# 3         4  Cerrado con éxito    2024-07-19 17:06:39.744000     Procede
# 4         5  Cerrado con éxito    2024-07-13 09:21:26.496000     Procede
# ..      ...                ...                           ...         ...
# 972     973            Abierto    2025-07-02 13:16:01.920000     Procede
# 973     974            Abierto    2025-07-02 13:41:11.328000     Procede
# 974     975            Abierto    2025-07-02 15:58:14.016000     Procede
# 975     976            Abierto    2025-07-02 16:20:23.712000     Procede
# 976     977            Abierto    2025-07-03 00:26:22.848000     Procede
#
#                  Marca temporal Nombre y apellido de quien solicita el ticket  \
# ...
