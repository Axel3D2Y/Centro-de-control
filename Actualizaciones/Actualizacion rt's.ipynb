# %%
import pandas as pd 
import numpy as np

# %%
rts_2= pd.read_excel(r"C:\Users\centro.control\Downloads\Rts-Sem-42-2025.xlsx")
sitios_sap = pd.read_excel(r"C:\Users\centro.control\Desktop\Monitor CMC\Sitios SAP.xlsx")

# %%
#Actualizar cada semana con las fechas correspondientes  de Domingo a Sábado
diccionariofechas= {
    'Domingo': 45935,
    'Lunes': 45936,
    'Martes': 45937,
    'Miercoles': 45938,
    'Jueves': 45939,
    'Viernes': 45940,
    'Sabado': 45941,
}

# %%
def rts_dia(dia):
    rts_x_dia = rts_2[rts_2[dia].notna() ][ ['Nombre', 'Sitio donde acude', 'Turno'] ]
    rts_x_dia['Dia semana'] = dia
    return rts_x_dia

def dia_a_fecha(dia):
    return diccionariofechas.get(dia, 'fecha no encontrada')

dias_semana = ['Domingo', 'Lunes', 'Martes', 'Miercole', 'Jueves', 'Viernes', 'Sabado']

# %%
rts_limpios = pd.DataFrame()
for dia in dias_semana:
    aux = []
    aux = pd.DataFrame(rts_dia(dia))
    rts_limpios = pd.concat([rts_limpios, aux], ignore_index=True)

# %%
rts_limpios['fecha'] = rts_limpios['Dia semana'].apply(dia_a_fecha)
rts_limpios['Nomenclatura'] = 'RT'
rts_limpios['Asistencia']= 1
cols = [
    'candidate_id', 'NumWeek', 'employment',
    'incidencia', 'Significado','Tipo'
]
rts_limpios[cols] = np.nan

# %%
sitios_sap
# Out:
#          SAP      Razón Social OK                   SITIO           RFC   id  \
# 0        NaN                  NaN              CAF PURINA           NaN    6
# 1        NaN                  NaN            CEDIS PURINA           NaN    8
# 2    CL03001  SERVICIOS LIVERPOOL   CORPORATIVO LIVERPOOL  SLI8007013R7   20
# 3        NaN                  NaN             GE SANTA FE           NaN   48
# 4    CL05201        TIP DE MEXICO           TIP DE MEXICO  TME931214KU6   49
# ..       ...                  ...                     ...           ...  ...
# 188      NaN                  NaN       CONTINNUO EVENTOS           NaN  383
# 189      NaN                  NaN     MEDICINA METABOLICA           NaN  384
# 190      NaN                  NaN                   SHEIN           NaN  385
# 191      NaN                  NaN   PLANET FITNESS ACOXPA           NaN  386
# 192      NaN                  NaN  PLANET FITNESS MIXCOAC           NaN  387
#
#                   NOMBRE COMERCIAL   EJECUTIVO OPS 2025    ZONA OPS  \
# 0                       CAF PURINA                  NaN         NaN
# 1                     CEDIS PURINA                  NaN         NaN
# 2    CL03001 CORPORATIVO LIVERPOOL         Abel Vázquez  CUAJIMALPA
# 3                      GE SANTA FE                  NaN         NaN
# 4            CL05201 TIP DE MEXICO       Karina Sánchez       NORTE
# ..                             ...                  ...         ...
# 188              CONTINNUO EVENTOS      Ángel Cervantes         NaN
# 189            MEDICINA METABOLICA      Ángel Cervantes         NaN
# 190                          SHEIN      Ángel Cervantes         NaN
# 191          PLANET FITNESS ACOXPA       Oscar Castillo         NaN
# 192         PLANET FITNESS MIXCOAC  Guillermina Vázquez         NaN
#
#     CATEGORIA DE SITIO                                DIRECCIÓN DEL SITIO  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2               GRANDE  MARIO PANI 200, SANTA FE, CONTADERO, CUAJIMALP...
# 3                  NaN                                                NaN
# 4                CHICO  AV. TEJOCOTES S/N LOTE 10, FRACC. INDUSTRIAL S...
# ..                 ...                                                ...
# 188                NaN                                                NaN
# 189                NaN                                                NaN
# 190                NaN                                                NaN
# 191                NaN                                                NaN
# 192                NaN                                                NaN
#
#        LATITUD   LONGITUD     tipo
# 0          NaN        NaN  NATURAL
# 1          NaN        NaN  NATURAL
# 2    19.359865 -99.274738  NATURAL
# 3          NaN        NaN  NATURAL
# 4    19.606874 -99.218071  NATURAL
# ..         ...        ...      ...
# 188        NaN        NaN  NATURAL
# 189        NaN        NaN  NATURAL
# 190        NaN        NaN  NATURAL
# 191        NaN        NaN  NATURAL
# 192        NaN        NaN  NATURAL
#
# [193 rows x 13 columns]

# %%
rts_limpios= pd.merge(
    rts_limpios,
    sitios_sap[['NOMBRE COMERCIAL', 'SITIO', 'id']],
    left_on='Sitio donde acude',
    right_on='NOMBRE COMERCIAL',
    how='left'
)

# %%
rts_limpios
# Out:
#                                   Nombre                Sitio donde acude  \
# 0         MOLINA HERNANDEZ MARCO ANTONIO          CL00302 UNITED AIRLINES
# 1     ESPINOZA HERNANDEZ BRANDON NEFTALI       CL00601 PLAZA ARKANA NORTE
# 2              MUÑOZ CRUZ JESSICA YAZMIN       CL00601 PLAZA ARKANA NORTE
# 3                GONZALEZ SANCHEZ ESTHER             CL02203 EUROVI OASIS
# 4              MALDONADO DEAQUINO ALICIA             CL02203 EUROVI OASIS
# ..                                   ...                              ...
# 274  GONZALEZ GUTIERREZ ALBERTO SANTIAGO       CL03005 LIVERPOOL COACALCO
# 275                GARCIA RAMIREZ VICTOR                   CL03301 MCCANN
# 276                    LOPEZ PEREZ MARIA  CL03401 MIYANA CENTRO COMERCIAL
# 277    VICTORIANO RODRIGUEZ KARLA BRENDA  CL03401 MIYANA CENTRO COMERCIAL
# 278        DARIO GONZALEZ DULCE JEANETTE             CL03402 MIYANA TORRE
#
#           Turno Dia semana  fecha Nomenclatura  Asistencia  candidate_id  \
# 0    VESPERTINO    Domingo  45935           RT           1           NaN
# 1      MATUTINO    Domingo  45935           RT           1           NaN
# 2    VESPERTINO    Domingo  45935           RT           1           NaN
# 3    VESPERTINO    Domingo  45935           RT           1           NaN
# 4    VESPERTINO    Domingo  45935           RT           1           NaN
# ..          ...        ...    ...          ...         ...           ...
# 274  VESPERTINO     Sabado  45941           RT           1           NaN
# 275    MATUTINO     Sabado  45941           RT           1           NaN
# 276  VESPERTINO     Sabado  45941           RT           1           NaN
# 277    MATUTINO     Sabado  45941           RT           1           NaN
# 278  VESPERTINO     Sabado  45941           RT           1           NaN
#
#      NumWeek  employment  incidencia  Significado  Tipo  \
# 0        NaN         NaN         NaN          NaN   NaN
# 1        NaN         NaN         NaN          NaN   NaN
# 2        NaN         NaN         NaN          NaN   NaN
# 3        NaN         NaN         NaN          NaN   NaN
# 4        NaN         NaN         NaN          NaN   NaN
# ..       ...         ...         ...          ...   ...
# 274      NaN         NaN         NaN          NaN   NaN
# 275      NaN         NaN         NaN          NaN   NaN
# 276      NaN         NaN         NaN          NaN   NaN
# 277      NaN         NaN         NaN          NaN   NaN
# 278      NaN         NaN         NaN          NaN   NaN
#
#                     NOMBRE COMERCIAL                    SITIO   id
# 0            CL00302 UNITED AIRLINES          UNITED AIRLINES  317
# 1         CL00601 PLAZA ARKANA NORTE       PLAZA ARKANA NORTE  322
# 2         CL00601 PLAZA ARKANA NORTE       PLAZA ARKANA NORTE  322
# 3               CL02203 EUROVI OASIS             EUROVI OASIS  354
# 4               CL02203 EUROVI OASIS             EUROVI OASIS  354
# ..                               ...                      ...  ...
# 274       CL03005 LIVERPOOL COACALCO       LIVERPOOL COACALCO  288
# 275                   CL03301 MCCANN                   MCCANN   67
# 276  CL03401 MIYANA CENTRO COMERCIAL  MIYANA CENTRO COMERCIAL  191
# 277  CL03401 MIYANA CENTRO COMERCIAL  MIYANA CENTRO COMERCIAL  191
# 278             CL03402 MIYANA TORRE             MIYANA TORRE  189
#
# [279 rows x 16 columns]

# %%
rts_limpios = rts_limpios[['id',
                    'candidate_id',
                    'SITIO',
                    'Nombre',
                    'employment',
                    'Turno',
                    'NumWeek',
                    'incidencia',
                    'fecha',
                    'Nomenclatura',
                    'Significado',
                    'Asistencia',
                    'Tipo']]

# %%
rts_limpios.rename(columns={
    '': 'sitio',
    'Nombre': 'nombre_completo',
    'Turno': 'turno'})
# Out:
#       id  candidate_id                    SITIO  \
# 0    317           NaN          UNITED AIRLINES
# 1    322           NaN       PLAZA ARKANA NORTE
# 2    322           NaN       PLAZA ARKANA NORTE
# 3    354           NaN             EUROVI OASIS
# 4    354           NaN             EUROVI OASIS
# ..   ...           ...                      ...
# 274  288           NaN       LIVERPOOL COACALCO
# 275   67           NaN                   MCCANN
# 276  191           NaN  MIYANA CENTRO COMERCIAL
# 277  191           NaN  MIYANA CENTRO COMERCIAL
# 278  189           NaN             MIYANA TORRE
#
#                          nombre_completo  employment       turno  NumWeek  \
# 0         MOLINA HERNANDEZ MARCO ANTONIO         NaN  VESPERTINO      NaN
# 1     ESPINOZA HERNANDEZ BRANDON NEFTALI         NaN    MATUTINO      NaN
# 2              MUÑOZ CRUZ JESSICA YAZMIN         NaN  VESPERTINO      NaN
# 3                GONZALEZ SANCHEZ ESTHER         NaN  VESPERTINO      NaN
# 4              MALDONADO DEAQUINO ALICIA         NaN  VESPERTINO      NaN
# ..                                   ...         ...         ...      ...
# 274  GONZALEZ GUTIERREZ ALBERTO SANTIAGO         NaN  VESPERTINO      NaN
# 275                GARCIA RAMIREZ VICTOR         NaN    MATUTINO      NaN
# 276                    LOPEZ PEREZ MARIA         NaN  VESPERTINO      NaN
# 277    VICTORIANO RODRIGUEZ KARLA BRENDA         NaN    MATUTINO      NaN
# 278        DARIO GONZALEZ DULCE JEANETTE         NaN  VESPERTINO      NaN
#
#      incidencia  fecha Nomenclatura  Significado  Asistencia  Tipo
# 0           NaN  45935           RT          NaN           1   NaN
# 1           NaN  45935           RT          NaN           1   NaN
# 2           NaN  45935           RT          NaN           1   NaN
# 3           NaN  45935           RT          NaN           1   NaN
# 4           NaN  45935           RT          NaN           1   NaN
# ..          ...    ...          ...          ...         ...   ...
# 274         NaN  45941           RT          NaN           1   NaN
# 275         NaN  45941           RT          NaN           1   NaN
# 276         NaN  45941           RT          NaN           1   NaN
# 277         NaN  45941           RT          NaN           1   NaN
# 278         NaN  45941           RT          NaN           1   NaN
#
# [279 rows x 13 columns]

# %%
rts_limpios
# Out:
#       id  candidate_id                    SITIO  \
# 0    317           NaN          UNITED AIRLINES
# 1    322           NaN       PLAZA ARKANA NORTE
# 2    322           NaN       PLAZA ARKANA NORTE
# 3    354           NaN             EUROVI OASIS
# 4    354           NaN             EUROVI OASIS
# ..   ...           ...                      ...
# 274  288           NaN       LIVERPOOL COACALCO
# 275   67           NaN                   MCCANN
# 276  191           NaN  MIYANA CENTRO COMERCIAL
# 277  191           NaN  MIYANA CENTRO COMERCIAL
# 278  189           NaN             MIYANA TORRE
#
#                                   Nombre  employment       Turno  NumWeek  \
# 0         MOLINA HERNANDEZ MARCO ANTONIO         NaN  VESPERTINO      NaN
# 1     ESPINOZA HERNANDEZ BRANDON NEFTALI         NaN    MATUTINO      NaN
# 2              MUÑOZ CRUZ JESSICA YAZMIN         NaN  VESPERTINO      NaN
# 3                GONZALEZ SANCHEZ ESTHER         NaN  VESPERTINO      NaN
# 4              MALDONADO DEAQUINO ALICIA         NaN  VESPERTINO      NaN
# ..                                   ...         ...         ...      ...
# 274  GONZALEZ GUTIERREZ ALBERTO SANTIAGO         NaN  VESPERTINO      NaN
# 275                GARCIA RAMIREZ VICTOR         NaN    MATUTINO      NaN
# 276                    LOPEZ PEREZ MARIA         NaN  VESPERTINO      NaN
# 277    VICTORIANO RODRIGUEZ KARLA BRENDA         NaN    MATUTINO      NaN
# 278        DARIO GONZALEZ DULCE JEANETTE         NaN  VESPERTINO      NaN
#
#      incidencia  fecha Nomenclatura  Significado  Asistencia  Tipo
# 0           NaN  45935           RT          NaN           1   NaN
# 1           NaN  45935           RT          NaN           1   NaN
# 2           NaN  45935           RT          NaN           1   NaN
# 3           NaN  45935           RT          NaN           1   NaN
# 4           NaN  45935           RT          NaN           1   NaN
# ..          ...    ...          ...          ...         ...   ...
# 274         NaN  45941           RT          NaN           1   NaN
# 275         NaN  45941           RT          NaN           1   NaN
# 276         NaN  45941           RT          NaN           1   NaN
# 277         NaN  45941           RT          NaN           1   NaN
# 278         NaN  45941           RT          NaN           1   NaN
#
# [279 rows x 13 columns]

# %%
rts_limpios.to_excel(r"C:\Users\centro.control\Documents\Limpieza de rts\Rts-Sem-42-2025-Limpio.xlsx",index=False)
