# %%
import pandas as pd 
import numpy as np

# %%
rts_2= pd.read_excel(r"C:\Users\centro.control\Downloads\Rts-Sem-29-2025.xlsx")
sitios_sap = pd.read_excel(r"C:\Users\centro.control\Desktop\Monitor CMC\Sitios SAP.xlsx")

# %%
#Actualizar cada semana con las fechas correspondientes  de Domingo a Sábado
diccionariofechas= {
    'Domingo': '03/08/2025',
    'Lunes': '04/08/2025',
    'Martes': '05/08/2025',
    'Miercoles': '06/08/2025',
    'Jueves': '07/08/2025',
    'Viernes': '08/08/2025',
    'Sabado': '09/08/2025',
}

# %%
def rts_dia(dia):
    rts_x_dia = rts_2[rts_2[dia].notna() ][ ['Nombre', 'Sitio donde acude', 'Turno'] ]
    rts_x_dia['Dia semana'] = dia
    return rts_x_dia

def dia_a_fecha(dia):
    return diccionariofechas.get(dia, 'fecha no encontrada')

dias_semana = ['Domingo', 'Lunes', 'Martes', 'Miercole', 'Jueves', 'Viernes', 'Sabado']

# %%
rts_limpios = pd.DataFrame()
for dia in dias_semana:
    aux = []
    aux = pd.DataFrame(rts_dia(dia))
    rts_limpios = pd.concat([rts_limpios, aux], ignore_index=True)

# %%
rts_limpios['fecha'] = rts_limpios['Dia semana'].apply(dia_a_fecha)
rts_limpios['Nomenclatura'] = 'RT'
rts_limpios['Asistencia']= 1
cols = [
    'candidate_id', 'NumWeek', 'employment',
    'incidencia', 'Significado','Tipo'
]
rts_limpios[cols] = np.nan

# %%
sitios_sap
# Out:
#          SAP                  Razón Social OK  \
# 0    CL00101                        4E GLOBAL
# 1    CL00102                        4E GLOBAL
# 2    CL00401             ALASKA AIRLINES, INC
# 3    CL00301            AMERICAN AIRLINES INC
# 4    CL00501  AMERICAN EXPRESS COMPANY MEXICO
# ..       ...                              ...
# 195      NaN                              NaN
# 196      NaN                              NaN
# 197      NaN                              NaN
# 198      NaN                              NaN
# 199      NaN                              NaN
#
#                                  SITIO           RFC   id  \
# 0                      4E GLOBAL CEDIS  EGL160502SC2  363
# 1                     4E GLOBAL PLANTA  EGL160502SC2  362
# 2                      ALASKA AIRLINES  AAI890301JJ3  347
# 3                    AMERICAN AIRLINES  AAI580414GA9  364
# 4                     AMERICAN EXPRESS  AEC810901298  251
# ..                                 ...           ...  ...
# 195                         CAF PURINA           NaN    6
# 196  LIVERPOOL JILOTEPEC 5 ADICIONALES           NaN  357
# 197        LIVERPOOL JILOTEPEC BARRIDO           NaN  357
# 198                          PRE ALTAS           NaN  341
# 199                  CONTINNUO EVENTOS           NaN  383
#
#                          NOMBRE COMERCIAL EJECUTIVO OPS 2025   ZONA OPS  \
# 0                 CL00101 4E GLOBAL CEDIS     Karina Sánchez      NORTE
# 1                CL00102 4E GLOBAL PLANTA     Karina Sánchez      NORTE
# 2                 CL00401 ALASKA AIRLINES       Abel Vázquez  AUDITORIO
# 3               CL00301 AMERICAN AIRLINES       Abel Vázquez  AUDITORIO
# 4    CL00501 AMERICAN EXPRESS PATRIOTISMO    Ángel Cervantes        SUR
# ..                                    ...                ...        ...
# 195                            CAF PURINA                NaN        NaN
# 196     LIVERPOOL JILOTEPEC 5 ADICIONALES                NaN        NaN
# 197           LIVERPOOL JILOTEPEC BARRIDO                NaN        NaN
# 198                    CCGENERI PRE ALTAS                NaN        NaN
# 199                     CONTINNUO EVENTOS                NaN        NaN
#
#     CATEGORIA DE SITIO                                DIRECCIÓN DEL SITIO  \
# 0                MENOR          MANZANA 005,54769 CUAUTITLAN IZCALLI, MEX
# 1                CHICO  AVENIDA 1 NORTE 15,PARQUE INDUSTRIAL CARTAGENA...
# 2                MENOR  REFORMA #483, COL. CUAUHTÉMOC, ALCALDÍA CUAUHT...
# 3                MENOR  Av. P.º de la Reforma 483, Cuauhtémoc, 06600 C...
# 4               GRANDE  AV. PATRIOTISMO 635, CD. DE LOS DEPORTES, BENI...
# ..                 ...                                                ...
# 195                NaN                                                NaN
# 196                NaN                                                NaN
# 197                NaN                                                NaN
# 198                NaN                                                NaN
# 199                NaN                                                NaN
#
#        LATITUD   LONGITUD
# 0    19.611039 -99.215023
# 1    19.644833 -99.156900
# 2    19.424332 -99.174476
# 3    19.424629 -99.174302
# 4    19.381645 -99.184100
# ..         ...        ...
# 195        NaN        NaN
# 196        NaN        NaN
# 197        NaN        NaN
# 198        NaN        NaN
# 199        NaN        NaN
#
# [200 rows x 12 columns]

# %%
rts_limpios= pd.merge(
    rts_limpios,
    sitios_sap[['NOMBRE COMERCIAL', 'SITIO', 'id']],
    left_on='Sitio donde acude',
    right_on='NOMBRE COMERCIAL',
    how='left'
)

# %%
rts_limpios
# Out:
#                             Nombre                     Sitio donde acude  \
# 0        RINCON CRUZ ROSARIO AIDEE            CL00601 PLAZA ARKANA NORTE
# 1          MARTINEZ ACUA GUADALUPE                 CL02201 EUROVI ACOXPA
# 2          TEZOCO QUIAHUA NICOLASA          CL03006 LIVERPOOL INTERLOMAS
# 3        SANCHEZ JIMENEZ ANA LAURA               CL00302 UNITED AIRLINES
# 4            PEREZ LOPEZ MAGDALENA  CL00501 AMERICAN EXPRESS PATRIOTISMO
# ..                             ...                                   ...
# 216    SALDAÑA NUÑEZ IVETTE IVONNE                    CL04701 SOHO HOUSE
# 217       SANCHEZ ALVARADO ROBERTO                    CL04701 SOHO HOUSE
# 218  TAVERA SANCHEZ ADRIANA JANETH                    CL04701 SOHO HOUSE
# 219      GONZALEZ DELGADO VERONICA          CL05501 ZAGO BAJA CALIFORNIA
# 220     PATIÑO LOPEZ NORMA CLAUDIA                      CL05801 DYNACAST
#
#           Turno Dia semana       fecha Nomenclatura  Asistencia  candidate_id  \
# 0      MATUTINO    Domingo  03/08/2025           RT           1           NaN
# 1      MATUTINO    Domingo  03/08/2025           RT           1           NaN
# 2      MATUTINO    Domingo  03/08/2025           RT           1           NaN
# 3    VESPERTINO      Lunes  04/08/2025           RT           1           NaN
# 4      NOCTURNO      Lunes  04/08/2025           RT           1           NaN
# ..          ...        ...         ...          ...         ...           ...
# 216    NOCTURNO     Sabado  09/08/2025           RT           1           NaN
# 217    NOCTURNO     Sabado  09/08/2025           RT           1           NaN
# 218    NOCTURNO     Sabado  09/08/2025           RT           1           NaN
# 219  VESPERTINO     Sabado  09/08/2025           RT           1           NaN
# 220  VESPERTINO     Sabado  09/08/2025           RT           1           NaN
#
#      NumWeek  employment  incidencia  Significado  Tipo  \
# 0        NaN         NaN         NaN          NaN   NaN
# 1        NaN         NaN         NaN          NaN   NaN
# 2        NaN         NaN         NaN          NaN   NaN
# 3        NaN         NaN         NaN          NaN   NaN
# 4        NaN         NaN         NaN          NaN   NaN
# ..       ...         ...         ...          ...   ...
# 216      NaN         NaN         NaN          NaN   NaN
# 217      NaN         NaN         NaN          NaN   NaN
# 218      NaN         NaN         NaN          NaN   NaN
# 219      NaN         NaN         NaN          NaN   NaN
# 220      NaN         NaN         NaN          NaN   NaN
#
#                          NOMBRE COMERCIAL                 SITIO   id
# 0              CL00601 PLAZA ARKANA NORTE    PLAZA ARKANA NORTE  322
# 1                   CL02201 EUROVI ACOXPA         EUROVI ACOXPA  355
# 2            CL03006 LIVERPOOL INTERLOMAS  LIVERPOOL INTERLOMAS  183
# 3                 CL00302 UNITED AIRLINES       UNITED AIRLINES  317
# 4    CL00501 AMERICAN EXPRESS PATRIOTISMO      AMERICAN EXPRESS  251
# ..                                    ...                   ...  ...
# 216                    CL04701 SOHO HOUSE            SOHO HOUSE  376
# 217                    CL04701 SOHO HOUSE            SOHO HOUSE  376
# 218                    CL04701 SOHO HOUSE            SOHO HOUSE  376
# 219          CL05501 ZAGO BAJA CALIFORNIA  ZAGO BAJA CALIFORNIA  245
# 220                      CL05801 DYNACAST              DYNACAST  379
#
# [221 rows x 16 columns]

# %%
rts_limpios = rts_limpios[['id',
                    'candidate_id',
                    'SITIO',
                    'Nombre',
                    'employment',
                    'Turno',
                    'NumWeek',
                    'incidencia',
                    'fecha',
                    'Nomenclatura',
                    'Significado',
                    'Asistencia',
                    'Tipo']]

# %%
rts_limpios.rename(columns={
    '': 'sitio',
    'Nombre': 'nombre_completo',
    'Turno': 'turno'})
# Out:
#       id  candidate_id                 SITIO                nombre_completo  \
# 0    322           NaN    PLAZA ARKANA NORTE      RINCON CRUZ ROSARIO AIDEE
# 1    355           NaN         EUROVI ACOXPA        MARTINEZ ACUA GUADALUPE
# 2    183           NaN  LIVERPOOL INTERLOMAS        TEZOCO QUIAHUA NICOLASA
# 3    317           NaN       UNITED AIRLINES      SANCHEZ JIMENEZ ANA LAURA
# 4    251           NaN      AMERICAN EXPRESS          PEREZ LOPEZ MAGDALENA
# ..   ...           ...                   ...                            ...
# 216  376           NaN            SOHO HOUSE    SALDAÑA NUÑEZ IVETTE IVONNE
# 217  376           NaN            SOHO HOUSE       SANCHEZ ALVARADO ROBERTO
# 218  376           NaN            SOHO HOUSE  TAVERA SANCHEZ ADRIANA JANETH
# 219  245           NaN  ZAGO BAJA CALIFORNIA      GONZALEZ DELGADO VERONICA
# 220  379           NaN              DYNACAST     PATIÑO LOPEZ NORMA CLAUDIA
#
#      employment       turno  NumWeek  incidencia       fecha Nomenclatura  \
# 0           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 1           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 2           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 3           NaN  VESPERTINO      NaN         NaN  04/08/2025           RT
# 4           NaN    NOCTURNO      NaN         NaN  04/08/2025           RT
# ..          ...         ...      ...         ...         ...          ...
# 216         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 217         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 218         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 219         NaN  VESPERTINO      NaN         NaN  09/08/2025           RT
# 220         NaN  VESPERTINO      NaN         NaN  09/08/2025           RT
#
#      Significado  Asistencia  Tipo
# 0            NaN           1   NaN
# 1            NaN           1   NaN
# 2            NaN           1   NaN
# 3            NaN           1   NaN
# 4            NaN           1   NaN
# ..           ...         ...   ...
# 216          NaN           1   NaN
# 217          NaN           1   NaN
# 218          NaN           1   NaN
# 219          NaN           1   NaN
# 220          NaN           1   NaN
#
# [221 rows x 13 columns]

# %%
rts_limpios
# Out:
#       id  candidate_id                 SITIO                         Nombre  \
# 0    322           NaN    PLAZA ARKANA NORTE      RINCON CRUZ ROSARIO AIDEE
# 1    355           NaN         EUROVI ACOXPA        MARTINEZ ACUA GUADALUPE
# 2    183           NaN  LIVERPOOL INTERLOMAS        TEZOCO QUIAHUA NICOLASA
# 3    317           NaN       UNITED AIRLINES      SANCHEZ JIMENEZ ANA LAURA
# 4    251           NaN      AMERICAN EXPRESS          PEREZ LOPEZ MAGDALENA
# ..   ...           ...                   ...                            ...
# 216  376           NaN            SOHO HOUSE    SALDAÑA NUÑEZ IVETTE IVONNE
# 217  376           NaN            SOHO HOUSE       SANCHEZ ALVARADO ROBERTO
# 218  376           NaN            SOHO HOUSE  TAVERA SANCHEZ ADRIANA JANETH
# 219  245           NaN  ZAGO BAJA CALIFORNIA      GONZALEZ DELGADO VERONICA
# 220  379           NaN              DYNACAST     PATIÑO LOPEZ NORMA CLAUDIA
#
#      employment       Turno  NumWeek  incidencia       fecha Nomenclatura  \
# 0           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 1           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 2           NaN    MATUTINO      NaN         NaN  03/08/2025           RT
# 3           NaN  VESPERTINO      NaN         NaN  04/08/2025           RT
# 4           NaN    NOCTURNO      NaN         NaN  04/08/2025           RT
# ..          ...         ...      ...         ...         ...          ...
# 216         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 217         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 218         NaN    NOCTURNO      NaN         NaN  09/08/2025           RT
# 219         NaN  VESPERTINO      NaN         NaN  09/08/2025           RT
# 220         NaN  VESPERTINO      NaN         NaN  09/08/2025           RT
#
#      Significado  Asistencia  Tipo
# 0            NaN           1   NaN
# 1            NaN           1   NaN
# 2            NaN           1   NaN
# 3            NaN           1   NaN
# 4            NaN           1   NaN
# ..           ...         ...   ...
# 216          NaN           1   NaN
# 217          NaN           1   NaN
# 218          NaN           1   NaN
# 219          NaN           1   NaN
# 220          NaN           1   NaN
#
# [221 rows x 13 columns]

# %%
# rts_limpios.to_excel(r"C:\Users\centro.control\Documents\Limpieza de rts\Rts-Sem-29-2025-Limpio.xlsx",index=False)
